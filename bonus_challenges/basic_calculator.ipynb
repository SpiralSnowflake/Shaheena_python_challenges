# %% [markdown]
# Challenge: Build a Basic Calculator
# Problem
# 1. Create a menu-driven calculator that lets the user choose an operation (add, subtract, multiply, divide), enter two numbers, and get the result.
#
# Example
# Choose operation: add
# Enter first number: 4
# Enter second number: 5
# Result: 9
# Your Task
# 1. Write a function for each operation
# 2. Prompt the user to select an operation and input numbers
# 3. Display the result
# 4. Handle invalid inputs and division by zero
# Concepts Tested
# Functions
# Conditional logic
# Input handling
# Stretch Ideas
# 2. Allow the user to keep using the calculator until they type "exit"
# 3. Save calculations to a log file
# 4. Add support for more operations like exponents or modulus

# %%
# Create a menu-driven calculator that lets the user choose an operation (add, subtract, multiply, divide), 
# enter two numbers, and get the result.
# 1. Write a function for each operation
def caladd(a,b):
    return(f"The sum of {a} and {b} is {a+b:.2f}")
def calsub(a,b):
    return(f"The difference of {a} and {b} is {a-b:.2f}")
def calmul(a,b):
    return(f"The product of {a} and {b} is {a*b:.2f}:")
def caldiv(a,b):
    try:
        if b!=0:
            return(f"The quotient of {a} and {b} is {a/b:.2f}:")
    except:
        if b==0:
            print("ZeroDivisionError")
    
# 2. Prompt the user to select an operation and input numbers
try:
    user_input = int(input("Calculator 🧮  \n What arithmetic operation do you want to do(please enter 1,2,3,4) :  1.➕add 2.➖subtract 3.✖️multiply 4.➗divide "))
    #print("Please enter the 2 numbers to add: ")
    #num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
    
    # 3. Display the result
    if user_input==1:
        print("Please enter the 2 numbers to add: ")
        num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
        print(caladd(num1,num2))
    elif user_input==2:
        print("Please enter the 2 numbers to subtract: ")
        num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
        print(calsub(num1,num2))
    elif user_input==3:
        print("Please enter the 2 numbers to multiply: ")
        num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
        print(calmul(num1,num2))
    elif user_input==4:
        print("Please enter the 2 numbers to divide: ")
        num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
        print(caldiv(num1,num2))
    else:
        print("Please enter a valid option")
# 4. Handle invalid inputs and division by zero
except:
     print("Please enter a valid number")
# Out:
# Please enter the 2 numbers to add:
# The sum of 2.0 and 4.6 is 6.60

# %%
#Allow the user to keep using the calculator until they type "exit"
# Create a menu-driven calculator that lets the user choose an operation (add, subtract, multiply, divide), 
# enter two numbers, and get the result.
# 1. Write a function for each operation
def caladd(a,b):
    return(f"The sum of {a} and {b} is {a+b:.2f}")
def calsub(a,b):
    return(f"The difference of {a} and {b} is {a-b:.2f}")
def calmul(a,b):
    return(f"The product of {a} and {b} is {a*b:.2f}:")
def caldiv(a,b):
    try:
        if b!=0:
            return(f"The quotient of {a} and {b} is {a/b:.2f}:")
    except:
        if b==0:
            print("ZeroDivisionError")
    
# 2. Prompt the user to select an operation and input numbers

try:
    i=True
    while i== True:
        user_input = int(input("Calculator 🧮  \n What arithmetic operation do you want to do(please enter 1,2,3,4,5) :  1.➕add 2.➖subtract 3.✖️multiply 4.➗divide 5. Exit"))
        #print("Please enter the 2 numbers to add: ")
        #num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
        
        # 3. Display the result
        if user_input==1:
            print("Please enter the 2 numbers to add: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(caladd(num1,num2))
        elif user_input==2:
            print("Please enter the 2 numbers to subtract: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(calsub(num1,num2))
        elif user_input==3:
            print("Please enter the 2 numbers to multiply: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(calmul(num1,num2))
        elif user_input==4:
            print("Please enter the 2 numbers to divide: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(caldiv(num1,num2))
        elif user_input==5:
            i=False
            break
        else:
            print("Please enter a valid option")
    # 4. Handle invalid inputs and division by zero
except:
     print("Please enter a valid number")
# Out:
# Please enter the 2 numbers to add:
# The sum of 4.0 and 5.0 is 9.00

# %%
#3. Save calculations to a log file

# 1. Write a function for each operation
def caladd(a,b):
    #return(f"The sum of {a} and {b} is {a+b:.2f}")
    with open('cal_log_file.txt', 'a') as f:
        f.write(f"The sum of {a} and {b} is {a+b:.2f}\n")
    return
def calsub(a,b):
    #return(f"The sum of {a} and {b} is {a-b:.2f}")
     with open('cal_log_file.txt', 'a') as f:
        f.write(f"The difference of {a} and {b} is {a-b:.2f}\n")
def calmul(a,b):
    #return(f"The sum of {a} and {b} is {a*b:.2f}:")
     with open('cal_log_file.txt', 'a') as f:
        f.write(f"The product of {a} and {b} is {a*b:.2f}\n")
def caldiv(a,b):
    try:
        if b!=0:
            #return(f"The sum of {a} and {b} is {a/b:.2f}:")
             with open('cal_log_file.txt', 'a') as f:
                f.write(f"The quotient of {a} and {b} is {a/b:.2f}\n")
    except:
        if b==0:
            #print("ZeroDivisionError")
            with open('cal_log_file.txt', 'a') as f:
                f.write(f"ZeroDivisionError as {a/b} is not applicable")
#save to log file function
# def save_file():
#     with open('cal_log_file.txt', 'a') as f:
#         f.write()
        
    
# 2. Prompt the user to select an operation and input numbers

try:
    i=True
    while i== True:
        user_input = int(input("Calculator 🧮  \n What arithmetic operation do you want to do(please enter 1,2,3,4,5) :  1.➕add 2.➖subtract 3.✖️multiply 4.➗divide 5. Exit"))
        #print("Please enter the 2 numbers to add: ")
        #num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
        
        # 3. Display the result
        if user_input==1:
            print("Please enter the 2 numbers to add: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            caladd(num1,num2)
        elif user_input==2:
            print("Please enter the 2 numbers to subtract: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(calsub(num1,num2))
        elif user_input==3:
            print("Please enter the 2 numbers to multiply: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(calmul(num1,num2))
        elif user_input==4:
            print("Please enter the 2 numbers to divide: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(caldiv(num1,num2))
        elif user_input==5:
            i=False
            break
        else:
            print("Please enter a valid option")
    # 4. Handle invalid inputs and division by zero
except:
     print("Please enter a valid number")
# Out:
# Please enter the 2 numbers to add:
# None

# %%
#4. Add support for more operations like exponents or modulus
# 1. Write a function for each operation
def caladd(a,b):
    return(f"The sum of {a} and {b} is {a+b:.2f}")
def calsub(a,b):
    return(f"The difference of {a} and {b} is {a-b:.2f}")
def calmul(a,b):
    return(f"The product of {a} and {b} is {a*b:.2f}:")
def caldiv(a,b):
    try:
        if b!=0:
            return(f"The quotient of {a} and {b} is {a/b:.2f}:")
    except:
        if b==0:
            print("ZeroDivisionError")
def calexpo(a,b):
    return(f"{a} to the power of {int(b)} is {a**b:.2f}:")
def calmod(a,b):
    return(f"{a} modulus {b} is {a%b:.2f}:")
    
# 2. Prompt the user to select an operation and input numbers

try:
    i=True
    while i== True:
        user_input = int(input("Calculator 🧮  \n What arithmetic operation do you want to do(please enter 1,2,3,4,5) :  1.➕add 2.➖subtract 3.✖️multiply 4.➗divide 5.^ exponenet 6.🔢%🔢 modulus 7.Exit"))
        #print("Please enter the 2 numbers to add: ")
        #num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
        
        # 3. Display the result
        if user_input==1:
            print("Please enter the 2 numbers to add: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(caladd(num1,num2))
        elif user_input==2:
            print("Please enter the 2 numbers to subtract: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(calsub(num1,num2))
        elif user_input==3:
            print("Please enter the 2 numbers to multiply: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(calmul(num1,num2))
        elif user_input==4:
            print("Please enter the 2 numbers to divide: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(caldiv(num1,num2))
        elif user_input==5:
            print("Please enter the 2 numbers to find exponenet: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(calexpo(num1,num2))
        elif user_input==6:
            print("Please enter the 2 numbers to find modulus: ")
            num1,num2 = float(input('Enter num1 : ')), float(input('Enter num2 : '))
            print(calmod(num1,num2))
        elif user_input==7:
            i=False
            break
        else:
            print("Please enter a valid option")
    # 4. Handle invalid inputs and division by zero
except:
     print("Please enter a valid number")
# Out:
# Please enter the 2 numbers to find modulus:
# 5.0 modulus 2.0 is 1.00:
# Please enter the 2 numbers to find exponenet:
# 3.0 to the power of 2 is 9.00:
